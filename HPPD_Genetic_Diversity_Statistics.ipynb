# %%
# !pip install -q --no-warn-conflicts malariagen_data
import malariagen_data
import pandas as pd
import plotly.express as px
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 44.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 54.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.5/302.5 kB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 62.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.2/210.2 kB 20.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 79.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.5 MB/s eta 0:00:00
#   Building wheel for dash-cytoscape (setup.py) ... done
#   Building wheel for asciitree (setup.py) ... done

# %%
ag3 = malariagen_data.Ag3()
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : gs://vo_agam_release/
# Data releases available : 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9
# Results cache           : None
# Cohorts analysis        : 20240418
# AIM analysis            : 20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 9.0.1
# Client location         : South Carolina, US
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact support@malariagen.net. For API documentation see
# https://malariagen.github.io/malariagen-data-python/v9.0.1/Ag3.html

# %%
# Genetic diversity

# %%
df_samples = ag3.sample_metadata(sample_sets="3.0")
df_samples
# Out:
#      sample_id partner_sample_id      contributor    country location  year  \
# 0     AR0047-C            LUA047       Joao Pinto     Angola   Luanda  2009
# 1     AR0049-C            LUA049       Joao Pinto     Angola   Luanda  2009
# 2     AR0051-C            LUA051       Joao Pinto     Angola   Luanda  2009
# 3     AR0061-C            LUA061       Joao Pinto     Angola   Luanda  2009
# 4     AR0078-C            LUA078       Joao Pinto     Angola   Luanda  2009
# ...        ...               ...              ...        ...      ...   ...
# 3076  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 3077  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 3078  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 3079  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 3080  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
#       month  latitude  longitude sex_call  ... admin1_name admin1_iso  \
# 0         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 1         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 2         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 3         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 4         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# ...     ...       ...        ...      ...  ...         ...        ...
# 3076     -1    53.409     -2.969        F  ...         NaN        NaN
# 3077     -1    53.409     -2.969        M  ...         NaN        NaN
# 3078     -1    53.409     -2.969        M  ...         NaN        NaN
# 3079     -1    53.409     -2.969        F  ...         NaN        NaN
# 3080     -1    53.409     -2.969        M  ...         NaN        NaN
#
#       admin2_name       taxon cohort_admin1_year  cohort_admin1_month  \
# 0          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 1          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 2          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 3          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 4          Luanda    coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04
# ...           ...         ...                ...                  ...
# 3076          NaN  unassigned                NaN                  NaN
# 3077          NaN  unassigned                NaN                  NaN
# 3078          NaN  unassigned                NaN                  NaN
# 3079          NaN  unassigned                NaN                  NaN
# 3080          NaN  unassigned                NaN                  NaN
#
#       cohort_admin1_quarter       cohort_admin2_year  \
# 0       AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 1       AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 2       AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 3       AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 4       AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# ...                     ...                      ...
# 3076                    NaN                      NaN
# 3077                    NaN                      NaN
# 3078                    NaN                      NaN
# 3079                    NaN                      NaN
# 3080                    NaN                      NaN
#
#              cohort_admin2_month       cohort_admin2_quarter
# 0     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 1     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 2     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 3     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 4     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# ...                          ...                         ...
# 3076                         NaN                         NaN
# 3077                         NaN                         NaN
# 3078                         NaN                         NaN
# 3079                         NaN                         NaN
# 3080                         NaN                         NaN
#
# [3081 rows x 32 columns]

# %%
## Let have a look on Angola samples
ag3.count_samples(
    sample_query="country == 'Angola'"
)
# Out:
# taxon                                            coluzzii
# country admin1_iso admin1_name admin2_name year
# Angola  AO-LUA     Luanda      Luanda      2009        81
#                                            2010         8

# %%
df_samples_AO = ag3.sample_metadata(
    sample_query="country == 'Angola'"
)
df_samples_AO.head()
# Out:
#   sample_id partner_sample_id contributor country location  year  month  \
# 0  AR0047-C            LUA047  Joao Pinto  Angola   Luanda  2009      4
# 1  AR0049-C            LUA049  Joao Pinto  Angola   Luanda  2009      4
# 2  AR0051-C            LUA051  Joao Pinto  Angola   Luanda  2009      4
# 3  AR0061-C            LUA061  Joao Pinto  Angola   Luanda  2009      4
# 4  AR0078-C            LUA078  Joao Pinto  Angola   Luanda  2009      4
#
#    latitude  longitude sex_call  ... admin1_name admin1_iso  admin2_name  \
# 0    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 1    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 2    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 3    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 4    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
#
#       taxon cohort_admin1_year  cohort_admin1_month  cohort_admin1_quarter  \
# 0  coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04    AO-LUA_colu_2009_Q2
# 1  coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04    AO-LUA_colu_2009_Q2
# 2  coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04    AO-LUA_colu_2009_Q2
# 3  coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04    AO-LUA_colu_2009_Q2
# 4  coluzzii   AO-LUA_colu_2009  AO-LUA_colu_2009_04    AO-LUA_colu_2009_Q2
#
#         cohort_admin2_year         cohort_admin2_month  \
# 0  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 1  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 2  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 3  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 4  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
#
#         cohort_admin2_quarter
# 0  AO-LUA_Luanda_colu_2009_Q2
# 1  AO-LUA_Luanda_colu_2009_Q2
# 2  AO-LUA_Luanda_colu_2009_Q2
# 3  AO-LUA_Luanda_colu_2009_Q2
# 4  AO-LUA_Luanda_colu_2009_Q2
#
# [5 rows x 32 columns]

# %%
df_samples_AO.groupby("cohort_admin2_year").size()
# Out:
# cohort_admin2_year
# AO-LUA_Luanda_colu_2009    81
# AO-LUA_Luanda_colu_2010     8
# dtype: int64

# %%
stats = ag3.cohort_diversity_stats(
    cohort="AO-LUA_colu_2009",
    cohort_size=30,
    region="2L:3,745,921-3,747,552",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
stats
# Out:
# Access SNP calls: ⠼ (0:00:22.72)
# Locate CDS_DEG_4 sites:   0%|          | 0/2 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/11 [00:00<?, ?it/s]
# cohort               AO-LUA_colu_2009
# theta_pi                     0.003612
# theta_pi_estimate            0.003612
# theta_pi_bias                     0.0
# theta_pi_std_err                  0.0
# theta_pi_ci_err                   0.0
# theta_pi_ci_low              0.003612
# theta_pi_ci_upp              0.003612
# theta_w                      0.010007
# theta_w_estimate             0.010007
# theta_w_bias                      0.0
# theta_w_std_err                   0.0
# theta_w_ci_err                    0.0
# theta_w_ci_low               0.010007
# theta_w_ci_upp               0.010007
# tajima_d                    -1.633303
# tajima_d_estimate           -1.633303
# tajima_d_bias                    -0.0
# tajima_d_std_err                  0.0
# tajima_d_ci_err                   0.0
# tajima_d_ci_low             -1.633303
# tajima_d_ci_upp             -1.633303
# taxon                        coluzzii
# year                             2009
# month                               4
# country                        Angola
# admin1_iso                     AO-LUA
# admin1_name                    Luanda
# admin2_name                    Luanda
# longitude                      13.302
# latitude                       -8.884
# dtype: object

# %%
## Let have a look on Burkina Faso samples
ag3.count_samples(
    sample_query= "country == 'Burkina Faso'"
)
# Out:
# taxon                                                       arabiensis  \
# country      admin1_iso admin1_name       admin2_name year
# Burkina Faso BF-01      Boucle du Mouhoun Kossi       2008           1
#              BF-02      Cascades          Comoe       2011           0
#                                                       2012           0
#                                                       2015           0
#                                                       2016           0
#              BF-06      Centre-Ouest      Sanguie     2008           0
#              BF-07      Centre-Sud        Bazega      2004           0
#              BF-09      Hauts-Bassins     Houet       2012           0
#                                                       2014          12
#                                                       2015          88
#                                                       2016          14
#                                                       2017           8
#                                                       2018           9
#                                                       2019          36
#              BF-11      Plateau Central   Oubritenga  2007           0
#                                                       2008           4
#
# taxon                                                       coluzzii  gambiae  \
# country      admin1_iso admin1_name       admin2_name year
# Burkina Faso BF-01      Boucle du Mouhoun Kossi       2008         4        0
#              BF-02      Cascades          Comoe       2011        18        0
#                                                       2012        63        0
#                                                       2015        33        0
#                                                       2016        53        0
#              BF-06      Centre-Ouest      Sanguie     2008         0        0
#              BF-07      Centre-Sud        Bazega      2004         0       13
#              BF-09      Hauts-Bassins     Houet       2012        82       99
#                                                       2014       146      170
#                                                       2015       183      141
#                                                       2016       167      104
#                                                       2017       183       52
#                                                       2018        16       18
#                                                       2019        43       16
#              BF-11      Plateau Central   Oubritenga  2007         0        0
#                                                       2008         3        0
#
# taxon                                                       gcx4  unassigned
# country      admin1_iso admin1_name       admin2_name year
# Burkina Faso BF-01      Boucle du Mouhoun Kossi       2008     0           0
#              BF-02      Cascades          Comoe       2011    41           0
#                                                       2012     0           0
#                                                       2015     0           0
#                                                       2016     0           0
#              BF-06      Centre-Ouest      Sanguie     2008     6           0
#              BF-07      Centre-Sud        Bazega      2004     0           0
#              BF-09      Hauts-Bassins     Houet       2012     0           0
#                                                       2014     0           0
#                                                       2015     0           0
#                                                       2016     0           1
#                                                       2017     0           0
#                                                       2018     0           0
#                                                       2019     0           0
#              BF-11      Plateau Central   Oubritenga  2007     4           0
#                                                       2008     2           0

# %%
df_samples_BFA = ag3.sample_metadata(
    sample_query="country == 'Burkina Faso'"
)
df_samples_BFA.head()
# Out:
#                   sample_id partner_sample_id  contributor       country  \
# 0  VBS25655-5561STDY9810298           BF16-13  Austin Burt  Burkina Faso
# 1  VBS25656-5561STDY9810299           BF16-14  Austin Burt  Burkina Faso
# 2  VBS25657-5561STDY9810300           BF16-15  Austin Burt  Burkina Faso
# 3  VBS25658-5561STDY9810301           BF16-16  Austin Burt  Burkina Faso
# 4  VBS25659-5561STDY9810302           BF16-17  Austin Burt  Burkina Faso
#
#   location  year  month  latitude  longitude sex_call  ...    admin1_name  \
# 0     Pala  2014      7    11.151     -4.235        F  ...  Hauts-Bassins
# 1     Pala  2014      7    11.151     -4.235        F  ...  Hauts-Bassins
# 2     Pala  2014      7    11.151     -4.235        F  ...  Hauts-Bassins
# 3     Pala  2014      7    11.151     -4.235        F  ...  Hauts-Bassins
# 4     Pala  2014      7    11.151     -4.235        F  ...  Hauts-Bassins
#
#   admin1_iso  admin2_name    taxon cohort_admin1_year  cohort_admin1_month  \
# 0      BF-09        Houet  gambiae    BF-09_gamb_2014   BF-09_gamb_2014_07
# 1      BF-09        Houet  gambiae    BF-09_gamb_2014   BF-09_gamb_2014_07
# 2      BF-09        Houet  gambiae    BF-09_gamb_2014   BF-09_gamb_2014_07
# 3      BF-09        Houet  gambiae    BF-09_gamb_2014   BF-09_gamb_2014_07
# 4      BF-09        Houet  gambiae    BF-09_gamb_2014   BF-09_gamb_2014_07
#
#    cohort_admin1_quarter     cohort_admin2_year       cohort_admin2_month  \
# 0     BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
# 1     BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
# 2     BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
# 3     BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
# 4     BF-09_gamb_2014_Q3  BF-09_Houet_gamb_2014  BF-09_Houet_gamb_2014_07
#
#       cohort_admin2_quarter
# 0  BF-09_Houet_gamb_2014_Q3
# 1  BF-09_Houet_gamb_2014_Q3
# 2  BF-09_Houet_gamb_2014_Q3
# 3  BF-09_Houet_gamb_2014_Q3
# 4  BF-09_Houet_gamb_2014_Q3
#
# [5 rows x 32 columns]

# %%
df_samples_BFA.groupby("cohort_admin2_year").size()
# Out:
# cohort_admin2_year
# BF-01_Kossi_arab_2008           1
# BF-01_Kossi_colu_2008           4
# BF-02_Comoe_colu_2011          18
# BF-02_Comoe_colu_2012          63
# BF-02_Comoe_colu_2015          33
# BF-02_Comoe_colu_2016          53
# BF-02_Comoe_gcx4_2011          41
# BF-06_Sanguie_gcx4_2008         6
# BF-07_Bazega_gamb_2004         13
# BF-09_Houet_arab_2014          12
# BF-09_Houet_arab_2015          88
# BF-09_Houet_arab_2016          14
# BF-09_Houet_arab_2017           8
# BF-09_Houet_arab_2018           9
# BF-09_Houet_arab_2019          36
# BF-09_Houet_colu_2012          82
# BF-09_Houet_colu_2014         146
# BF-09_Houet_colu_2015         183
# BF-09_Houet_colu_2016         167
# BF-09_Houet_colu_2017         183
# BF-09_Houet_colu_2018          16
# BF-09_Houet_colu_2019          43
# BF-09_Houet_gamb_2012          99
# BF-09_Houet_gamb_2014         170
# BF-09_Houet_gamb_2015         141
# BF-09_Houet_gamb_2016         104
# BF-09_Houet_gamb_2017          52
# BF-09_Houet_gamb_2018          18
# BF-09_Houet_gamb_2019          16
# BF-11_Oubritenga_arab_2008      4
# BF-11_Oubritenga_colu_2008      3
# BF-11_Oubritenga_gcx4_2007      4
# BF-11_Oubritenga_gcx4_2008      2
# dtype: int64

# %%
df_stats_BFA_admin2_year = ag3.diversity_stats(
    sample_query="country == 'Burkina Faso'",
    cohorts="admin2_year",
    cohort_size=30,
    region="2L:3,745,921-3,747,552",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
df_stats_BFA_admin2_year
# Out:
# Cohort (BF-01_Kossi_arab_2008) has insufficient samples (1) for requested cohort size (30), dropping.
# Cohort (BF-01_Kossi_colu_2008) has insufficient samples (4) for requested cohort size (30), dropping.
# Cohort (BF-02_Comoe_colu_2011) has insufficient samples (18) for requested cohort size (30), dropping.
# Cohort (BF-06_Sanguie_gcx4_2008) has insufficient samples (6) for requested cohort size (30), dropping.
# Cohort (BF-07_Bazega_gamb_2004) has insufficient samples (13) for requested cohort size (30), dropping.
# Cohort (BF-09_Houet_arab_2014) has insufficient samples (12) for requested cohort size (30), dropping.
# Cohort (BF-09_Houet_arab_2016) has insufficient samples (14) for requested cohort size (30), dropping.
# Cohort (BF-09_Houet_arab_2017) has insufficient samples (8) for requested cohort size (30), dropping.
# Cohort (BF-09_Houet_arab_2018) has insufficient samples (9) for requested cohort size (30), dropping.
# Cohort (BF-09_Houet_colu_2018) has insufficient samples (16) for requested cohort size (30), dropping.
# Cohort (BF-09_Houet_gamb_2018) has insufficient samples (18) for requested cohort size (30), dropping.
# Cohort (BF-09_Houet_gamb_2019) has insufficient samples (16) for requested cohort size (30), dropping.
# Cohort (BF-11_Oubritenga_arab_2008) has insufficient samples (4) for requested cohort size (30), dropping.
# Cohort (BF-11_Oubritenga_colu_2008) has insufficient samples (3) for requested cohort size (30), dropping.
# Cohort (BF-11_Oubritenga_gcx4_2007) has insufficient samples (4) for requested cohort size (30), dropping.
# Cohort (BF-11_Oubritenga_gcx4_2008) has insufficient samples (2) for requested cohort size (30), dropping.
# Compute SNP allele counts:   0%|          | 0/11 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/11 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/11 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/11 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/24 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/malariagen_data/anopheles.py:1446: RuntimeWarning: invalid value encountered in scalar divide
#   tajima_d_data = d_data / d_stdev_data
# /usr/local/lib/python3.10/dist-packages/malariagen_data/anopheles.py:1480: RuntimeWarning: invalid value encountered in scalar divide
#   tajima_d_j = d_j / d_stdev_j
# Compute SNP allele counts:   0%|          | 0/19 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/malariagen_data/anopheles.py:1446: RuntimeWarning: invalid value encountered in scalar divide
#   tajima_d_data = d_data / d_stdev_data
# /usr/local/lib/python3.10/dist-packages/malariagen_data/anopheles.py:1480: RuntimeWarning: invalid value encountered in scalar divide
#   tajima_d_j = d_j / d_stdev_j
# Compute SNP allele counts:   0%|          | 0/19 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/24 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/29 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/24 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/29 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/19 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/19 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/29 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/29 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/24 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/24 [00:00<?, ?it/s]
#                    cohort  theta_pi  theta_pi_estimate  theta_pi_bias  \
# 0   BF-02_Comoe_colu_2012  0.013070           0.013070   3.452100e-16
# 1   BF-02_Comoe_colu_2015  0.015518           0.015518   3.452100e-16
# 2   BF-02_Comoe_colu_2016  0.011262           0.011262   3.452100e-16
# 3   BF-02_Comoe_gcx4_2011  0.010117           0.010117  -3.452100e-16
# 4   BF-09_Houet_arab_2015  0.000000           0.000000   0.000000e+00
# 5   BF-09_Houet_arab_2019  0.000000           0.000000   0.000000e+00
# 6   BF-09_Houet_colu_2012  0.011096           0.011096   0.000000e+00
# 7   BF-09_Houet_colu_2014  0.011119           0.011119   3.452100e-16
# 8   BF-09_Houet_colu_2015  0.009962           0.009962  -3.452100e-16
# 9   BF-09_Houet_colu_2016  0.012938           0.012938   0.000000e+00
# 10  BF-09_Houet_colu_2017  0.011465           0.011465  -3.452100e-16
# 11  BF-09_Houet_colu_2019  0.012878           0.012878   0.000000e+00
# 12  BF-09_Houet_gamb_2012  0.010991           0.010991   0.000000e+00
# 13  BF-09_Houet_gamb_2014  0.011571           0.011571   0.000000e+00
# 14  BF-09_Houet_gamb_2015  0.011062           0.011062  -6.904199e-16
# 15  BF-09_Houet_gamb_2016  0.009736           0.009736   3.452100e-16
# 16  BF-09_Houet_gamb_2017  0.010448           0.010448   0.000000e+00
#
#     theta_pi_std_err  theta_pi_ci_err  theta_pi_ci_low  theta_pi_ci_upp  \
# 0       2.447129e-17     9.592568e-17         0.013070         0.013070
# 1       2.447129e-17     9.592568e-17         0.015518         0.015518
# 2       2.447129e-17     9.592568e-17         0.011262         0.011262
# 3       2.447129e-17     9.592568e-17         0.010117         0.010117
# 4       0.000000e+00     0.000000e+00         0.000000         0.000000
# 5       0.000000e+00     0.000000e+00         0.000000         0.000000
# 6       0.000000e+00     0.000000e+00         0.011096         0.011096
# 7       2.447129e-17     9.592568e-17         0.011119         0.011119
# 8       2.447129e-17     9.592568e-17         0.009962         0.009962
# 9       0.000000e+00     0.000000e+00         0.012938         0.012938
# 10      2.447129e-17     9.592568e-17         0.011465         0.011465
# 11      0.000000e+00     0.000000e+00         0.012878         0.012878
# 12      0.000000e+00     0.000000e+00         0.010991         0.010991
# 13      0.000000e+00     0.000000e+00         0.011571         0.011571
# 14      4.894257e-17     1.918514e-16         0.011062         0.011062
# 15      2.447129e-17     9.592568e-17         0.009736         0.009736
# 16      0.000000e+00     0.000000e+00         0.010448         0.010448
#
#      theta_w  theta_w_estimate  ...  tajima_d_ci_upp       taxon  year  \
# 0   0.031452          0.031452  ...        -1.834490    coluzzii  2012
# 1   0.041459          0.041459  ...        -2.022734    coluzzii  2015
# 2   0.015726          0.015726  ...        -0.801069    coluzzii  2016
# 3   0.015726          0.015726  ...        -1.006533        gcx4  2011
# 4   0.000000          0.000000  ...              NaN  arabiensis  2015
# 5   0.000000          0.000000  ...              NaN  arabiensis  2019
# 6   0.017156          0.017156  ...        -1.013050    coluzzii  2012
# 7   0.025733          0.025733  ...        -1.737416    coluzzii  2014
# 8   0.017156          0.017156  ...        -1.202587    coluzzii  2015
# 9   0.028593          0.028593  ...        -1.698504    coluzzii  2016
# 10  0.015726          0.015726  ...        -0.764572    coluzzii  2017
# 11  0.022874          0.022874  ...        -1.314514    coluzzii  2019
# 12  0.014296          0.014296  ...        -0.640351     gambiae  2012
# 13  0.015726          0.015726  ...        -0.745648     gambiae  2014
# 14  0.014296          0.014296  ...        -0.626489     gambiae  2015
# 15  0.011437          0.011437  ...        -0.392363     gambiae  2016
# 16  0.014296          0.014296  ...        -0.745414     gambiae  2017
#
#                      month       country  admin1_iso    admin1_name  \
# 0                       -1  Burkina Faso       BF-02       Cascades
# 1                       -1  Burkina Faso       BF-02       Cascades
# 2                       -1  Burkina Faso       BF-02       Cascades
# 3                       -1  Burkina Faso       BF-02       Cascades
# 4             [1, 2, 4, 7]  Burkina Faso       BF-09  Hauts-Bassins
# 5                  [8, 10]  Burkina Faso       BF-09  Hauts-Bassins
# 6                        7  Burkina Faso       BF-09  Hauts-Bassins
# 7                  [7, 10]  Burkina Faso       BF-09  Hauts-Bassins
# 8                   [4, 7]  Burkina Faso       BF-09  Hauts-Bassins
# 9           [6, 8, 10, 12]  Burkina Faso       BF-09  Hauts-Bassins
# 10  [2, 4, 5, 7, 8, 9, 10]  Burkina Faso       BF-09  Hauts-Bassins
# 11                 [8, 10]  Burkina Faso       BF-09  Hauts-Bassins
# 12                       7  Burkina Faso       BF-09  Hauts-Bassins
# 13                 [7, 10]  Burkina Faso       BF-09  Hauts-Bassins
# 14               [1, 2, 7]  Burkina Faso       BF-09  Hauts-Bassins
# 15              [6, 8, 10]  Burkina Faso       BF-09  Hauts-Bassins
# 16           [4, 7, 8, 10]  Burkina Faso       BF-09  Hauts-Bassins
#
#     admin2_name  longitude   latitude
# 0         Comoe  -4.800000  10.700000
# 1         Comoe  -4.800000  10.700000
# 2         Comoe  -4.800000  10.700000
# 3         Comoe  -4.800000  10.700000
# 4         Houet  -4.235000  11.151000
# 5         Houet  -4.350056  11.183639
# 6         Houet  -4.356390  11.223768
# 7         Houet  -4.394527  11.236390
# 8         Houet  -4.362574  11.236852
# 9         Houet  -4.405725  11.235275
# 10        Houet  -4.441049  11.235317
# 11        Houet  -4.475674  11.228512
# 12        Houet  -4.290061  11.194657
# 13        Houet  -4.279612  11.191512
# 14        Houet  -4.277645  11.190504
# 15        Houet  -4.264625  11.193038
# 16        Houet  -4.274269  11.162288
#
# [17 rows x 31 columns]

# %%
df_stats_BFA_admin2_year.columns
# Out:
# Index(['cohort', 'theta_pi', 'theta_pi_estimate', 'theta_pi_bias',
#        'theta_pi_std_err', 'theta_pi_ci_err', 'theta_pi_ci_low',
#        'theta_pi_ci_upp', 'theta_w', 'theta_w_estimate', 'theta_w_bias',
#        'theta_w_std_err', 'theta_w_ci_err', 'theta_w_ci_low', 'theta_w_ci_upp',
#        'tajima_d', 'tajima_d_estimate', 'tajima_d_bias', 'tajima_d_std_err',
#        'tajima_d_ci_err', 'tajima_d_ci_low', 'tajima_d_ci_upp', 'taxon',
#        'year', 'month', 'country', 'admin1_iso', 'admin1_name', 'admin2_name',
#        'longitude', 'latitude'],
#       dtype='object')

# %%
px.bar(
    data_frame=df_stats_BFA_admin2_year,
    x="cohort",
    y="theta_pi_estimate",
    error_y="theta_pi_ci_err",
    color="taxon",
    height=450,
    width=500,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bbc5adc9-8c91-4b1a-aa45-637d9fe6b065" class="plotly-graph-div" style="height:450px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbc5adc9-8c91-4b1a-aa45-637d9fe6b065")) {                    Plotly.newPlot(                        "bbc5adc9-8c91-4b1a-aa45-637d9fe6b065",                        [{"alignmentgroup":"True","error_y":{"array":[9.592567871821893e-17,9.592567871821893e-17,9.592567871821893e-17,0.0,9.592567871821893e-17,9.592567871821893e-17,0.0,9.592567871821893e-17,0.0]},"hovertemplate":"taxon=coluzzii\u003cbr\u003ecohort=%{x}\u003cbr\u003etheta_pi_estimate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"coluzzii","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-02_Comoe_colu_2012","BF-02_Comoe_colu_2015","BF-02_Comoe_colu_2016","BF-09_Houet_colu_2012","BF-09_Houet_colu_2014","BF-09_Houet_colu_2015","BF-09_Houet_colu_2016","BF-09_Houet_colu_2017","BF-09_Houet_colu_2019"],"xaxis":"x","y":[0.01306967984934052,0.015517890772127714,0.011261770244820748,0.011096045197740111,0.011118644067796264,0.00996233521657285,0.01293785310734463,0.011465160075329913,0.01287758945386064],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[9.592567871821893e-17]},"hovertemplate":"taxon=gcx4\u003cbr\u003ecohort=%{x}\u003cbr\u003etheta_pi_estimate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gcx4","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gcx4","offsetgroup":"gcx4","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-02_Comoe_gcx4_2011"],"xaxis":"x","y":[0.010116760828625579],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0,0.0]},"hovertemplate":"taxon=arabiensis\u003cbr\u003ecohort=%{x}\u003cbr\u003etheta_pi_estimate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"arabiensis","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_arab_2015","BF-09_Houet_arab_2019"],"xaxis":"x","y":[0.0,0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0,0.0,1.9185135743643786e-16,9.592567871821893e-17,0.0]},"hovertemplate":"taxon=gambiae\u003cbr\u003ecohort=%{x}\u003cbr\u003etheta_pi_estimate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gambiae","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014","BF-09_Houet_gamb_2015","BF-09_Houet_gamb_2016","BF-09_Houet_gamb_2017"],"xaxis":"x","y":[0.010990583804143125,0.011570621468926554,0.011062146892656057,0.009736346516007188,0.010448210922787193],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %%
def plot_diversity_stats(
    df_stats,
    color=None,
    height=450,
    template="plotly_white"
):

    # set up common plotting parameters
    hover_name = "cohort"
    hover_data = [
        "taxon",
        "country",
        "admin1_iso",
        "admin1_name",
        "admin2_name",
        "year",
        "month",
    ]
    labels = {
        'theta_pi_estimate': r'$\widehat{\theta}_{\pi}$',
        'theta_w_estimate': r'$\widehat{\theta}_{w}$',
        'tajima_d_estimate': r'$D$',
        'cohort': "Cohort",
        'taxon': 'Taxon',
        'country': "Country",
    }
    category_orders = {
        "taxon": ["arabiensis", "gambiae", "gcx3", "coluzzii", "gcx1", "gcx2"],
    }
    width = 300 + 30 * len(df_stats)

    # nucleotide diversity bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="theta_pi_estimate",
        error_y="theta_pi_ci_err",
        title="Nucleotide diversity",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # watterson estimator bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="theta_w_estimate",
        error_y="theta_w_ci_err",
        title="Watterson estimator",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # tajima's d bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="tajima_d_estimate",
        error_y="tajima_d_ci_err",
        title="Tajima's D",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # scatter plot comparing diversity estimators
    fig = px.scatter(
        data_frame=df_stats,
        x="theta_pi_estimate",
        y="theta_w_estimate",
        error_x="theta_pi_ci_err",
        error_y="theta_w_ci_err",
        title="Diversity estimators",
        color=color,
        width=500,
        height=500,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

# %%
plot_diversity_stats(df_stats_BFA_admin2_year, color="taxon")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="853bae0f-b108-446a-9ad9-d8d1d53cb55b" class="plotly-graph-div" style="height:450px; width:810px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("853bae0f-b108-446a-9ad9-d8d1d53cb55b")) {                    Plotly.newPlot(                        "853bae0f-b108-446a-9ad9-d8d1d53cb55b",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[1,2,4,7]],["arabiensis","Burkina Faso","BF-09","Hauts-Bassins","Houet",2019,[8,10]]],"error_y":{"array":[0.0,0.0]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTaxon=%{customdata[0]}\u003cbr\u003eCohort=%{x}\u003cbr\u003e$\\widehat{\\theta}_{\\pi}$=%{y}\u003cbr\u003eCountry=%{customdata[1]}\u003cbr\u003eadmin1_iso=%{customdata[2]}\u003cbr\u003eadmin1_name=%{customdata[3]}\u003cbr\u003eadmin2_name=%{customdata[4]}\u003cbr\u003eyear=%{customdata[5]}\u003cbr\u003emonth=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BF-09_Houet_arab_2015","BF-09_Houet_arab_2019"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_arab_2015","BF-09_Houet_arab_2019"],"xaxis":"x","y":[0.0,0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,[7,10]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[1,2,7]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2016,[6,8,10]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2017,[4,7,8,10]]],"error_y":{"array":[0.0,0.0,1.9185135743643786e-16,9.592567871821893e-17,0.0]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTaxon=%{customdata[0]}\u003cbr\u003eCohort=%{x}\u003cbr\u003e$\\widehat{\\theta}_{\\pi}$=%{y}\u003cbr\u003eCountry=%{customdata[1]}\u003cbr\u003eadmin1_iso=%{customdata[2]}\u003cbr\u003eadmin1_name=%{customdata[3]}\u003cbr\u003eadmin2_name=%{customdata[4]}\u003cbr\u003eyear=%{customdata[5]}\u003cbr\u003emonth=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014","BF-09_Houet_gamb_2015","BF-09_Houet_gamb_2016","BF-09_Houet_gamb_2017"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014","BF-09_Houet_gamb_2015","BF-09_Houet_gamb_2016","BF-09_Houet_gamb_2017"],"xaxis":"x","y":[0.010990583804143125,0.011570621468926554,0.011062146892656057,0.009736346516007188,0.010448210922787193],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2012,-1],["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2015,-1],["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2016,-1],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,[7,10]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[4,7]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2016,[6,8,10,12]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2017,[2,4,5,7,8,9,10]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2019,[8,10]]],"error_y":{"array":[9.592567871821893e-17,9.592567871821893e-17,9.592567871821893e-17,0.0,9.592567871821893e-17,9.592567871821893e-17,0.0,9.592567871821893e-17,0.0]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="59a688e1-593d-4ff5-ab10-085d5bfa0bdc" class="plotly-graph-div" style="height:450px; width:810px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59a688e1-593d-4ff5-ab10-085d5bfa0bdc")) {                    Plotly.newPlot(                        "59a688e1-593d-4ff5-ab10-085d5bfa0bdc",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[1,2,4,7]],["arabiensis","Burkina Faso","BF-09","Hauts-Bassins","Houet",2019,[8,10]]],"error_y":{"array":[0.0,0.0]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTaxon=%{customdata[0]}\u003cbr\u003eCohort=%{x}\u003cbr\u003e$\\widehat{\\theta}_{w}$=%{y}\u003cbr\u003eCountry=%{customdata[1]}\u003cbr\u003eadmin1_iso=%{customdata[2]}\u003cbr\u003eadmin1_name=%{customdata[3]}\u003cbr\u003eadmin2_name=%{customdata[4]}\u003cbr\u003eyear=%{customdata[5]}\u003cbr\u003emonth=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BF-09_Houet_arab_2015","BF-09_Houet_arab_2019"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_arab_2015","BF-09_Houet_arab_2019"],"xaxis":"x","y":[0.0,0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,[7,10]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[1,2,7]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2016,[6,8,10]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2017,[4,7,8,10]]],"error_y":{"array":[9.592567871821893e-17,1.9185135743643786e-16,9.592567871821893e-17,9.592567871821893e-17,9.592567871821893e-17]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTaxon=%{customdata[0]}\u003cbr\u003eCohort=%{x}\u003cbr\u003e$\\widehat{\\theta}_{w}$=%{y}\u003cbr\u003eCountry=%{customdata[1]}\u003cbr\u003eadmin1_iso=%{customdata[2]}\u003cbr\u003eadmin1_name=%{customdata[3]}\u003cbr\u003eadmin2_name=%{customdata[4]}\u003cbr\u003eyear=%{customdata[5]}\u003cbr\u003emonth=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014","BF-09_Houet_gamb_2015","BF-09_Houet_gamb_2016","BF-09_Houet_gamb_2017"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014","BF-09_Houet_gamb_2015","BF-09_Houet_gamb_2016","BF-09_Houet_gamb_2017"],"xaxis":"x","y":[0.014296322934586525,0.015725955228044868,0.014296322934586525,0.011437058347669152,0.014296322934586525],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2012,-1],["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2015,-1],["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2016,-1],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,[7,10]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[4,7]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2016,[6,8,10,12]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2017,[2,4,5,7,8,9,10]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2019,[8,10]]],"error_y":{"array":[3.837027148728757e-16,0.0,1.9185135743643786e-16,1.9185135743643786e-16,1.9185135743643786e-16,1.9185135743643786e-16,1.9185135743643786e-16,1.91851 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7394d59e-d0a4-437c-9410-1d76ccf87b80" class="plotly-graph-div" style="height:450px; width:810px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7394d59e-d0a4-437c-9410-1d76ccf87b80")) {                    Plotly.newPlot(                        "7394d59e-d0a4-437c-9410-1d76ccf87b80",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[1,2,4,7]],["arabiensis","Burkina Faso","BF-09","Hauts-Bassins","Houet",2019,[8,10]]],"error_y":{"array":[null,null]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTaxon=%{customdata[0]}\u003cbr\u003eCohort=%{x}\u003cbr\u003e$D$=%{y}\u003cbr\u003eCountry=%{customdata[1]}\u003cbr\u003eadmin1_iso=%{customdata[2]}\u003cbr\u003eadmin1_name=%{customdata[3]}\u003cbr\u003eadmin2_name=%{customdata[4]}\u003cbr\u003eyear=%{customdata[5]}\u003cbr\u003emonth=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BF-09_Houet_arab_2015","BF-09_Houet_arab_2019"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_arab_2015","BF-09_Houet_arab_2019"],"xaxis":"x","y":[null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,[7,10]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[1,2,7]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2016,[6,8,10]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2017,[4,7,8,10]]],"error_y":{"array":[1.2278486875932023e-14,0.0,6.1392434379660114e-15,3.0696217189830057e-15,0.0]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTaxon=%{customdata[0]}\u003cbr\u003eCohort=%{x}\u003cbr\u003e$D$=%{y}\u003cbr\u003eCountry=%{customdata[1]}\u003cbr\u003eadmin1_iso=%{customdata[2]}\u003cbr\u003eadmin1_name=%{customdata[3]}\u003cbr\u003eadmin2_name=%{customdata[4]}\u003cbr\u003eyear=%{customdata[5]}\u003cbr\u003emonth=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014","BF-09_Houet_gamb_2015","BF-09_Houet_gamb_2016","BF-09_Houet_gamb_2017"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014","BF-09_Houet_gamb_2015","BF-09_Houet_gamb_2016","BF-09_Houet_gamb_2017"],"xaxis":"x","y":[-0.640351334322194,-0.7456476335017885,-0.6264889218907117,-0.3923628251999932,-0.7454138285395322],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2012,-1],["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2015,-1],["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2016,-1],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,[7,10]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[4,7]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2016,[6,8,10,12]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2017,[2,4,5,7,8,9,10]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2019,[8,10]]],"error_y":{"array":[1.2278486875932023e-14,2.4556973751864046e-14,1.2278486875932023e-14,1.2278486875932023e-14,1.2278486875932023e-14,1.2278486875932023e-14,3.683546062779607e-14,6.1392434379660114e-15,1.2278486875932023e-14]},"hovertemplate":"\ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6a73d75c-7fae-49b7-9fd9-1037c73d52ae" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a73d75c-7fae-49b7-9fd9-1037c73d52ae")) {                    Plotly.newPlot(                        "6a73d75c-7fae-49b7-9fd9-1037c73d52ae",                        [{"customdata":[["arabiensis","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[1,2,4,7]],["arabiensis","Burkina Faso","BF-09","Hauts-Bassins","Houet",2019,[8,10]]],"error_x":{"array":[0.0,0.0]},"error_y":{"array":[0.0,0.0]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTaxon=%{customdata[0]}\u003cbr\u003e$\\widehat{\\theta}_{\\pi}$=%{x}\u003cbr\u003e$\\widehat{\\theta}_{w}$=%{y}\u003cbr\u003eCountry=%{customdata[1]}\u003cbr\u003eadmin1_iso=%{customdata[2]}\u003cbr\u003eadmin1_name=%{customdata[3]}\u003cbr\u003eadmin2_name=%{customdata[4]}\u003cbr\u003eyear=%{customdata[5]}\u003cbr\u003emonth=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BF-09_Houet_arab_2015","BF-09_Houet_arab_2019"],"legendgroup":"arabiensis","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"arabiensis","orientation":"v","showlegend":true,"x":[0.0,0.0],"xaxis":"x","y":[0.0,0.0],"yaxis":"y","type":"scatter"},{"customdata":[["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,[7,10]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[1,2,7]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2016,[6,8,10]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2017,[4,7,8,10]]],"error_x":{"array":[0.0,0.0,1.9185135743643786e-16,9.592567871821893e-17,0.0]},"error_y":{"array":[9.592567871821893e-17,1.9185135743643786e-16,9.592567871821893e-17,9.592567871821893e-17,9.592567871821893e-17]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTaxon=%{customdata[0]}\u003cbr\u003e$\\widehat{\\theta}_{\\pi}$=%{x}\u003cbr\u003e$\\widehat{\\theta}_{w}$=%{y}\u003cbr\u003eCountry=%{customdata[1]}\u003cbr\u003eadmin1_iso=%{customdata[2]}\u003cbr\u003eadmin1_name=%{customdata[3]}\u003cbr\u003eadmin2_name=%{customdata[4]}\u003cbr\u003eyear=%{customdata[5]}\u003cbr\u003emonth=%{customdata[6]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014","BF-09_Houet_gamb_2015","BF-09_Houet_gamb_2016","BF-09_Houet_gamb_2017"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.010990583804143125,0.011570621468926554,0.011062146892656057,0.009736346516007188,0.010448210922787193],"xaxis":"x","y":[0.014296322934586525,0.015725955228044868,0.014296322934586525,0.011437058347669152,0.014296322934586525],"yaxis":"y","type":"scatter"},{"customdata":[["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2012,-1],["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2015,-1],["coluzzii","Burkina Faso","BF-02","Cascades","Comoe",2016,-1],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,[7,10]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2015,[4,7]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2016,[6,8,10,12]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2017,[2,4,5,7,8,9,10]],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2019,[8,10]]],"error_x":{"array":[9.592567871821893e-17,9.592567871821893e-17,9.592567871821893e-17,0.0,9.592567871821893e-17,9.592567871821893e-17,0.0,9.592567871821893e-17,0.0]},"error_y":{"array":[3.837027148728757e-16 ...
